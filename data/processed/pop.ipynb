# %%
import pandas as pd

df = pd.read_csv("final_balanced_dataset.csv")

df.head()
# Out:
#    Unnamed: 0  nli_label                                          reasoning  \
# 0        2420          1  الدليل يشير إلى أن المقترح هو دراسة الجدوى وال...
# 1         644          0  الدليل المقدم لا يوضح بشكل واضح ما إذا كان الأ...
# 2         286          2  الادعاء يُشير إلى احتمالية أن يكون برنامج حمدو...
# 3         292          0  الادعاء يقول إن تحرير الأقصى تم بفضل المقاومة....
# 4        1577          2  من الملاحظ أن الدليل يشير إلى أنه من ثوابت الت...
#
#                                                claim  \
# 0  المقترح هو دراسه الجدوي والاثار المترتبه علي ت...
# 1  الادعاء الرئيسي هو ان القوائم المشاركه في الان...
# 2  برنامج حمدوك الحكومي الجديد قد يخلق استقطابا و...
# 3           اصبحنا اقرب لتحرير الاقصي بفضل المقاومه.
# 4  لن يشارك التيار الوطني الحر في حكومه سعد الحري...
#
#                                             evidence
# 0  وقال المسحل لبرنامج "في المرمي": المقترح هو در...
# 1  يتمتع بشعبيه وقبول عند غالبيه التيارات"، وبدان...
# ...

# %%
df["ID"] = df["Unnamed: 0"]
df_fianl = df[["ID","nli_label", "claim", "evidence"]]

df_fianl.head()
# Out:
#      ID  nli_label                                              claim  \
# 0  2420          1  المقترح هو دراسه الجدوي والاثار المترتبه علي ت...
# 1   644          0  الادعاء الرئيسي هو ان القوائم المشاركه في الان...
# 2   286          2  برنامج حمدوك الحكومي الجديد قد يخلق استقطابا و...
# 3   292          0           اصبحنا اقرب لتحرير الاقصي بفضل المقاومه.
# 4  1577          2  لن يشارك التيار الوطني الحر في حكومه سعد الحري...
#
#                                             evidence
# 0  وقال المسحل لبرنامج "في المرمي": المقترح هو در...
# 1  يتمتع بشعبيه وقبول عند غالبيه التيارات"، وبدان...
# 2  توافق وطني بين مكونات مجتمع غني بتنوعه الثقافي...
# 3  الاقصي»، اجتماعات منفصله مع من «الاطار التنسيق...
# 4  الذي له خصوصيه سنيه، ومن ثوابتنا ان نكون داعمي...

# %%
df_fianl.to_csv("final_balanced_dataset.csv")
