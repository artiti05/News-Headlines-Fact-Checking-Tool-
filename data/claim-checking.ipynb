# %%
import pandas as pd

df = pd.read_csv(r'processed\nli_dataset_optimized.csv')
df.head(10)
# Out:
#                                                claim  \
# 0             قطر تقود عملية دبلوماسية لخفض التصعيد.
# 1             قطر تقود عملية دبلوماسية لخفض التصعيد.
# 2  ادعاؤه هو: منعت سلطات مطار القاهرة رجل الأعمال...
# 3  ادعاؤه هو: منعت سلطات مطار القاهرة رجل الأعمال...
# 4  ادعاء النص الرئيسي هو:\nشدّدت وزيرة الداخلية ا...
# 5  ادعاء النص الرئيسي هو:\nشدّدت وزيرة الداخلية ا...
# 6   الاردن وصل لذروة الموجة الثانية من فيروس كورونا.
# 7   الاردن وصل لذروة الموجة الثانية من فيروس كورونا.
# 8     بايدن قد يكون آخر رئيس ديمقراطي مؤيد لإسرائيل.
# 9     بايدن قد يكون آخر رئيس ديمقراطي مؤيد لإسرائيل.
#
#                                             evidence  \
# 0  كشف مسؤول إسرائيلي بارز، الأحد، أن مصر وقطر وت...
# 1  نقلت صحيفة طهران تايمز عن سعيد خطيب زاده، المت...
# 2  ثلاثة من صحفيي الجزيرة هم الاسترالي بيتر غريست...
# 3  منعت سلطات مطار القاهرة رجل الأعمال المصري، أح...
# 4  July 28, 2020 - سعيا منها للحد من الهجرة غير ا...
# 5  وزيرة الداخلية الإيطالية تشدد على التزام بلاده...
# ...

# %%
df['nli_label'].value_counts()
# Out:
# nli_label
# 0    6304
# 1    1355
# 2     883
# Name: count, dtype: int64
