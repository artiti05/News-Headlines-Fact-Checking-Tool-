# %%
import pandas as pd

df = pd.read_csv(r"data\processed\nli_dataset_optimized.csv")

df.head()
# Out:
#                                                claim  \
# 0  اعترف معه أن اعتقال باسم عوض الله كان بسبب تهم...
# 1  اعترف معه أن اعتقال باسم عوض الله كان بسبب تهم...
# 2  صاروخ يصيب سفينة إيرانية بالبحر المتوسط.. واشت...
# 3  صاروخ يصيب سفينة إيرانية بالبحر المتوسط.. واشت...
# 4  إيران عمدت خلال الفترة الماضية، إلى تشكيل جماع...
#
#                                             evidence  \
# 0  أصدرت محكمة أردنية حكما بالسجن 15 عاما على رئي...
# 1  سواليف\n\nباسم عوض الله شغل العديد من المناصب ...
# 2  أتلانتا، الولايات المتحدة (CNN)-- تعرضت سفينة ...
# 3  صاروخ يصيب سفينة إيرانية بالبحر المتوسط.. واشت...
# 4  إذا كنت تعتقد أن هذا الإجراء تم عن طريق الخطأ،...
#
#                                         evidence_url  \
# 0     https://www.bbc.com/arabic/middleeast-56662254
# 1                                              local
# 2  https://arabic.cnn.com/middle-east/article/202...
# 3                                              local
# ...

# %%
cols = ['claim', 'evidence', 'reasoning']

for col in cols:
    print(df[col][1], end="\n\n")
# Out:
# اعترف معه أن اعتقال باسم عوض الله كان بسبب تهم بالتآمر على البلاد.
#
# سواليف
#
# باسم عوض الله شغل العديد من المناصب الكبيرة في الحكومة الأردنية
#
# أثار الوزير ورئيس الديوان الملكي السابق في الأردن، باسم عوض الله، جدلا كبيرا عندما اعتقل مع الشخصيات السياسية المتهمة بالتآمر ع
#
# النص لم يثبت أو ينف الادعاء بشكل قاطع.
